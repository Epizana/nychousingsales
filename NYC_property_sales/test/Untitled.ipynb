# %%
import pandas as pd

# %%
test1 = pd.read_csv('before_2010.csv', low_memory = False)

# %%
test1.sample(50)
# Out:
#        BOROUGH               NEIGHBORHOOD  \
# 60032        1  MIDTOWN WEST
# 65417        1  UPPER EAST SIDE (59-79)
# 8472         4  FLUSHING-SOUTH
# 19599        4  SO. JAMAICA-BAISLEY PARK
# 43294        1  UPPER EAST SIDE (79-96)
# 52779        1  HARLEM-CENTRAL
# 37689        1  MIDTOWN WEST
# 38491        1  MIDTOWN WEST
# 51800        1  GREENWICH VILLAGE-WEST
# 38829        1  MIDTOWN WEST
# 58610        1  MIDTOWN WEST
# 14089        4  LONG ISLAND CITY
# 44617        1  UPPER WEST SIDE (59-79)
# 24276        2  BAYCHESTER
# 67945        1  UPPER WEST SIDE (59-79)
# 14578        4  LONG ISLAND CITY
# 60835        1  MIDTOWN WEST
# 32486        1  HARLEM-CENTRAL
# 9374         4  FOREST HILLS
# 52642        1  HARLEM-CENTRAL
# 1423         4  BAYSIDE
# 40500        1  SOHO
# 49566        1  FINANCIAL
# 6894         4  FLUSHING-NORTH
# 10751        4  GLENDALE
# 11271        4  HOLLIS
# 63912        1  UPPER EAST SIDE (59-79)
# 54670        1  MANHATTAN VALLEY
# ...

# %%
test1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72105 entries, 0 to 72104
# Data columns (total 22 columns):
# BOROUGH                           72105 non-null int64
# NEIGHBORHOOD                      72105 non-null object
# BUILDING.CLASS.CATEGORY           72105 non-null object
# TAX.CLASS.AT.PRESENT              72105 non-null object
# BLOCK                             72105 non-null int64
# LOT                               72105 non-null int64
# EASE.MENT                         54809 non-null object
# BUILDING.CLASS.AT.PRESENT         72105 non-null object
# ADDRESS                           72105 non-null object
# APARTMENT.NUMBER                  72105 non-null object
# ZIP.CODE                          72105 non-null int64
# RESIDENTIAL.UNITS                 72105 non-null int64
# COMMERCIAL.UNITS                  72105 non-null object
# TOTAL.UNITS                       72105 non-null object
# LAND.SQUARE.FEET                  72105 non-null object
# ...

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer, sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, tupleize_cols=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
#     Read a comma-separated values (csv) file into DataFrame.
#
# ...
